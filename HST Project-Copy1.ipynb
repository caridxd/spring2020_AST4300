# %%
from __future__ import print_function
import numpy as np
from math import *
import matplotlib 
import matplotlib.pyplot as plt

# %%
# Note: by the time I reach 6, I was told to use the RA and Dec to find out which objects were which and 
# so at that point, I started using the actual NGC#### instead of Missing#

# %%
#Getting the data into python:
#From the data, getting the infromation from each specific column.
#For the variables, totmagf6 = F606W_TOTMAG and totmagf8 = F814W_TOTMAG.
#To make graphing esier, I chose to do the math in the x axis and y axis variables
#Likewise, I masked certain outliers to get a good depiction of the CMD and the focus is on the Main Sequence

e3 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_06_wfpc2_f814w_f606w_wf/hst_10775_06_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_e3 = e3[:,7]
totmagf8_e3 = e3[:,8]
xe3 = totmagf6_e3-totmagf8_e3
ye3 = totmagf6_e3
mask1 =  (ye3 < 50.) & (ye3 > -50.) & (xe3 < 8.) & (xe3 > -8.)

ngc362 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_30_wfpc2_f814w_f606w_wf/hst_10775_30_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc362 = ngc362[:,7]
totmagf8_ngc362 = ngc362[:,8]
xngc362 = totmagf6_ngc362-totmagf8_ngc362
yngc362 = totmagf6_ngc362
mask2 = (yngc362 < 50.) & (yngc362 > -50.) & (xngc362 < 2.) & (xngc362 > -5.)

missing_1 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_34_wfpc2_f814w_f606w_wf/hst_10775_34_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_missing_1 = missing_1[:,7]
totmagf8_missing_1 = missing_1[:,8]
xmissing_1 = totmagf6_missing_1-totmagf8_missing_1
ymissing_1 = totmagf6_missing_1
mask3 = (xmissing_1 > -10.) & (xmissing_1 < 10.) & (ymissing_1 > -50.) & (ymissing_1 < 30.)

ngc6218 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_44_wfpc2_f814w_f606w_wf/hst_10775_44_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc6218 = ngc6218[:,7]
totmagf8_ngc6218 = ngc6218[:,8]
xngc6218 = totmagf6_ngc6218-totmagf8_ngc6218
yngc6218 = totmagf6_ngc6218
mask4 = (yngc6218 < 50.) & (yngc6218 > -50.) & (xngc6218 < 10.) & (xngc6218 > -2.)

missing_2 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_45_wfpc2_f814w_f606w_wf/hst_10775_45_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_missing_2 = missing_2[:,7]
totmagf8_missing_2 = missing_2[:,8]
xmissing_2 = totmagf6_missing_2-totmagf8_missing_2
ymissing_2 = totmagf6_missing_2
mask5 = (xmissing_2 > 0) & (xmissing_2 < 10.) & (ymissing_2 > -50.) & (ymissing_2 < 30.)

ngc6656 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_48_wfpc2_f814w_f606w_wf/hst_10775_48_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc6656 = ngc6656[:,7]
totmagf8_ngc6656 = ngc6656[:,8]
xngc6656 = totmagf6_ngc6656-totmagf8_ngc6656
yngc6656 = totmagf6_ngc6656
mask6 = (yngc6656 < 50.) & (yngc6656 > -50.) & (xngc6656 < 25.) & (xngc6656 > 0.)

ngc104 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_60_wfpc2_f814w_f606w_wf/hst_10775_60_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc104 = ngc104[:,7]
totmagf8_ngc104 = ngc104[:,8]
xngc104 = totmagf6_ngc104-totmagf8_ngc104
yngc104 = totmagf6_ngc104
mask7 = (yngc104 < 50.) & (yngc104 > -50.) & (xngc104 < 25.) & (xngc104 > -0.5)

ngc6254 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_62_wfpc2_f814w_f606w_wf/hst_10775_62_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc6254 = ngc6254[:,7]
totmagf8_ngc6254 = ngc6254[:,8]
xngc6254 = totmagf6_ngc6254-totmagf8_ngc6254
yngc6254 = totmagf6_ngc6254
mask8 = (yngc6254 < 25.) & (yngc6254 > -50.) & (xngc6254 < 2.) & (xngc6254 > -2.)

missing_3 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_63_wfpc2_f814w_f606w_wf/hst_10775_63_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_missing_3 = missing_3[:,7]
totmagf8_missing_3 = missing_3[:,8]
xmissing_3 = totmagf6_missing_3-totmagf8_missing_3
ymissing_3 = totmagf6_missing_3
mask9 = (xmissing_3 > 0.) & (xmissing_3 < 3.) & (ymissing_3 > -50.) & (ymissing_3 < 30.)

ngc6121 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_64_wfpc2_f814w_f606w_wf/hst_10775_64_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc6121 = ngc6121[:,7]
totmagf8_ngc6121 = ngc6121[:,8]
xngc6121 = totmagf6_ngc6121-totmagf8_ngc6121
yngc6121 = totmagf6_ngc6121
mask10 = (yngc6121 < 50.) & (yngc6121 > -50.) & (xngc6121 < 25.) & (xngc6121 > -25.)

ngc6397 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_65_wfpc2_f814w_f606w_wf/hst_10775_65_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc6397 = ngc6397[:,7]
totmagf8_ngc6397 = ngc6397[:,8]
xngc6397 = totmagf6_ngc6397-totmagf8_ngc6397
yngc6397 = totmagf6_ngc6397
mask11 = (yngc6397 < 50.) & (yngc6397 > -50.) & (xngc6397 < 25.) & (xngc6397 > -25.)

missing_4 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_66_wfpc2_f814w_f606w_wf/hst_10775_66_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_missing_4 = missing_4[:,7]
totmagf8_missing_4 = missing_4[:,8]
xmissing_4 = totmagf6_missing_4-totmagf8_missing_4
ymissing_4 = totmagf6_missing_4
mask12 = (xmissing_4 > 0.) & (xmissing_4 < 1.75) & (ymissing_4 > -50.) & (ymissing_4 < 30.)

missing_5 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_a7_wfpc2_f814w_f606w_wf/hst_10775_a7_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_missing_5 = missing_5[:,7]
totmagf8_missing_5 = missing_5[:,8]
xmissing_5 = totmagf6_missing_5-totmagf8_missing_5
ymissing_5 = totmagf6_missing_5
mask13 = (xmissing_5 > 0.) & (xmissing_5 < 1.) & (ymissing_5 > -50.) & (ymissing_5 < 30.)

ngc6838 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_a8_wfpc2_f814w_f606w_wf/hst_10775_a8_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc6838 = ngc6838[:,7]
totmagf8_ngc6838 = ngc6838[:,8]
xngc6838 = totmagf6_ngc6838-totmagf8_ngc6838
yngc6838 = totmagf6_ngc6838
mask14 = (yngc6838 < 50.) & (yngc6838 > -50.) & (xngc6838 < 2.5) & (xngc6838 > 0.)

ngc4833 = np.genfromtxt('C:/Users/cbc93/Desktop/Spring 2020/AST4300/HstProject/Data/hst_10775_ac_wfpc2_f814w_f606w_wf/hst_10775_ac_wfpc2_multiwave_wf_sexphot_trm.cat')
totmagf6_ngc4833 = ngc4833[:,7]
totmagf8_ngc4833 = ngc4833[:,8]
xngc4833 = totmagf6_ngc4833-totmagf8_ngc4833
yngc4833 = totmagf6_ngc4833
mask15 = (yngc4833 < 50.) & (yngc4833 > -50.) & (xngc4833 < 25.) & (xngc4833 > 0.)

# %%
#Graphs: 
#Vertical Axis is flipped such that brighter magnitudes are at the top
print("2: Color Magnitude Diagrams")

plt.title('Color-Magnitude Diagram: E3')    
plt.scatter(xe3[mask1],ye3[mask1])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC362')    
plt.scatter(xngc362[mask2],yngc362[mask2])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: Missing 1')    
plt.scatter(xmissing_1[mask3],ymissing_1[mask3])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC6218')    
plt.scatter(xngc6218[mask4],yngc6218[mask4])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: Missing 2')    
plt.scatter(xmissing_2[mask5],ymissing_2[mask5])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC6656')    
plt.scatter(xngc6656[mask6],yngc6656[mask6])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC104')    
plt.scatter(xngc104[mask7],yngc104[mask7])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC6254')    
plt.scatter(xngc6254[mask8],yngc6254[mask8])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: Missing 3')    
plt.scatter(xmissing_3[mask9],ymissing_3[mask9])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC6121')    
plt.scatter(xngc6121[mask10],yngc6121[mask10])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC6397')    
plt.scatter(xngc6397[mask11],yngc6397[mask11])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: Missing 4')    
plt.scatter(xmissing_4[mask12],ymissing_4[mask12])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: Missing 5')    
plt.scatter(xmissing_5[mask13],ymissing_5[mask13])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC6838')    
plt.scatter(xngc6838[mask14],yngc6838[mask14])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()

plt.title('Color-Magnitude Diagram: NGC4833')    
plt.scatter(xngc4833[mask15],yngc4833[mask15])
plt.xlabel("F606W_TOTMAG - F814W_TOTMAG")
plt.ylabel("F606W_TOTMAG")
plt.gca().invert_yaxis()
plt.show()
# Out:
# 2: Color Magnitude Diagrams

# %%
print("3. Select one cluster as the standard:")
print("NGC104")
# Out:
# 3. Select one cluster as the standard:
# NGC104

# %%
# Masking, here it gets the index of the good values and puts them in a list 
good_e3 = []
for i in range (len(totmagf6_e3)):
    if xe3[i]> 0.5 and xe3[i]< 1.6 and ye3[i]>18. and ye3[i]<22.:
        good_e3.append(i )

good_ngc362 = []
for i in range (len(totmagf6_ngc362)):
    if xngc362[i]> 0. and xngc362[i]< 0.6 and yngc362[i]>18. and yngc362[i]<23.:
        good_ngc362.append(i)
        
good_missing1 = []
for i in range (len(totmagf6_missing_1)):
    if xmissing_1[i]> 0.2 and xmissing_1[i]< 1. and ymissing_1[i]>18. and ymissing_1[i]<23.:
        good_missing1.append(i)

good_ngc6218 = []
for i in range (len(totmagf6_ngc6218)):
    if xngc6218[i]> 0.2 and xngc6218[i]< 0.9 and yngc6218[i]>18. and yngc6218[i]<22.:
        good_ngc6218.append(i)
        
good_missing2 = []
for i in range (len(totmagf6_missing_2)):
    if xmissing_2[i]> 0.4 and xmissing_2[i]< 2.0 and ymissing_2[i]>17. and ymissing_2[i]<23.:
        good_missing2.append(i)

good_ngc6656 = []
for i in range (len(totmagf6_ngc6656)):
    if xngc6656[i]> 0.3 and xngc6656[i]< 1.25 and yngc6656[i]>17. and yngc6656[i]<23.:
        good_ngc6656.append(i)
        
good_ngc104 = []
for i in range (len(totmagf6_ngc104)):
    if xngc104[i]> 0.0 and xngc104[i]< 1.7 and yngc104[i]>16.8 and yngc104[i]<23.:
        good_ngc104.append(i)

good_ngc6254 = []
for i in range (len(totmagf6_ngc6254)):
    if xngc6254[i]> 0.25 and xngc6254[i]< 1. and yngc6254[i]>17.5 and yngc6254[i]<22.:
        good_ngc6254.append(i)
        
good_missing3 = []
for i in range (len(totmagf6_missing_3)):
    if xmissing_3[i]> 0.3 and xmissing_3[i]< 1.0 and ymissing_3[i]>17. and ymissing_3[i]<22.5:
        good_missing3.append(i)

good_ngc6121 = []
for i in range (len(totmagf6_ngc6121)):
    if xngc6121[i]> 0.3 and xngc6121[i]< 1.75 and yngc6121[i]>16.5 and yngc6121[i]<23.:
        good_ngc6121.append(i)

good_ngc6397 = []
for i in range (len(totmagf6_ngc6397)):
    if xngc6397[i]> 0.2 and xngc6397[i]< 1.0 and yngc6397[i]>16. and yngc6397[i]<22.:
        good_ngc6397.append(i)

good_missing4 = []
for i in range (len(totmagf6_missing_4)):
    if xmissing_4[i]> 0.1 and xmissing_4[i]< 1.1 and ymissing_4[i]>17. and ymissing_4[i]<23.5:
        good_missing4.append(i)

good_missing5 = []
for i in range (len(totmagf6_missing_5)):
    if xmissing_5[i]> 0.1 and xmissing_5[i]< 0.9 and ymissing_5[i]>17. and ymissing_5[i]<23.:
        good_missing5.append(i)
        
good_ngc6838 = []
for i in range (len(totmagf6_ngc6838)):
    if xngc6838[i]> 0.3 and xngc6838[i]< 1.75 and yngc6838[i]>16.5 and yngc6838[i]<23.:
        good_ngc6838.append(i)

good_ngc4833 = []
for i in range (len(totmagf6_ngc4833)):
    if xngc4833[i]> 0.3 and xngc4833[i]< 1.7 and yngc4833[i]>16. and yngc4833[i]<23.5:
        good_ngc4833.append(i)

# %%
print("4. Determine the vertical shift and error value using NGC104 as the reference:")
print()

#shift and error:
#shift was calculated using the mean value of the cluster subtracted by the mean value of the reference
#error was calculated using the standard error formula

f6_mean_ngc104 = sum(totmagf6_ngc104[good_ngc104])/len(totmagf6_ngc104[good_ngc104])

f6_mean_e3 = sum(totmagf6_e3[good_e3])/len(totmagf6_e3[good_e3])
f6_difference_e3 = abs(f6_mean_ngc104-f6_mean_e3)
stderr_e3 = (np.std(totmagf6_e3[good_e3]))/(np.sqrt(len(totmagf6_e3[good_e3])))
print("Shift For E3:", f6_difference_e3)
print("Error:", stderr_e3)
print()

f6_mean_ngc362 = sum(totmagf6_ngc362[good_ngc362])/len(totmagf6_ngc362[good_ngc362])
f6_difference_ngc362 = abs(f6_mean_ngc104-f6_mean_ngc362)
stderr_ngc362 = (np.std(totmagf6_ngc362[good_ngc362]))/(np.sqrt(len(totmagf6_ngc362)))
print("Shift For NGCC362:", f6_difference_ngc362)
print("Error:", stderr_ngc362)
print()

f6_mean_missing1 = sum(totmagf6_missing_1[good_missing1])/len(totmagf6_missing_1[good_missing1])
f6_difference_missing1 = abs(f6_mean_ngc104-f6_mean_missing1)
stderr_missing1 = (np.std(totmagf6_missing_1[good_missing1]))/(np.sqrt(len(totmagf6_missing_1[good_missing1])))
print("Shift For Missing1:", f6_difference_missing1)
print("Error:", stderr_missing1)
print()

f6_mean_ngc6218 = sum(totmagf6_ngc6218[good_ngc6218])/len(totmagf6_ngc6218[good_ngc6218])
f6_difference_ngc6218 = abs(f6_mean_ngc104-f6_mean_ngc6218)
stderr_ngc6218 = (np.std(totmagf6_ngc6218[good_ngc6218]))/(np.sqrt(len(totmagf6_ngc6218[good_ngc6218])))
print("Shift For NGC6218:", f6_difference_ngc6218)
print("Error:", stderr_ngc6218)
print()

f6_mean_missing2 = sum(totmagf6_missing_2[good_missing2])/len(totmagf6_missing_2[good_missing2])
f6_difference_missing2 = abs(f6_mean_ngc104-f6_mean_missing2)
stderr_missing2 = (np.std(totmagf6_missing_2[good_missing2]))/(np.sqrt(len(totmagf6_missing_2[good_missing2])))
print("Shift For Missing2:", f6_difference_missing2)
print("Error:", stderr_missing2)
print()

f6_mean_ngc6656 = sum(totmagf6_ngc6656[good_ngc6656])/len(totmagf6_ngc6656[good_ngc6656])
f6_difference_ngc6656 = abs(f6_mean_ngc104-f6_mean_ngc6656)
stderr_ngc6656 = (np.std(totmagf6_ngc6656[good_ngc6656]))/(np.sqrt(len(totmagf6_ngc6656[good_ngc6656])))
print("Shift For NGC6656:", f6_difference_ngc6656)
print("Error:", stderr_ngc6656)
print()

f6_mean_ngc6254 = sum(totmagf6_ngc6254[good_ngc6254])/len(totmagf6_ngc6254[good_ngc6254])
f6_difference_ngc6254 = abs(f6_mean_ngc104-f6_mean_ngc6254)
stderr_ngc6254 = (np.std(totmagf6_ngc6254[good_ngc6254]))/(np.sqrt(len(totmagf6_ngc6254[good_ngc6254])))
print("Shift For NGC6254:", f6_difference_ngc6254)
print("Error:", stderr_ngc6254)
print()

f6_mean_missing3 = sum(totmagf6_missing_3[good_missing3])/len(totmagf6_missing_3[good_missing3])
f6_difference_missing3 = abs(f6_mean_ngc104-f6_mean_missing3)
stderr_missing3 = (np.std(totmagf6_missing_3[good_missing3]))/(np.sqrt(len(totmagf6_missing_3[good_missing3])))
print("Shift For Missing3:", f6_difference_missing3)
print("Error:", stderr_missing3)
print()

f6_mean_ngc6121 = sum(totmagf6_ngc6121[good_ngc6121])/len(totmagf6_ngc6121[good_ngc6121])
f6_difference_ngc6121 = abs(f6_mean_ngc104-f6_mean_ngc6121)
stderr_ngc6121 = (np.std(totmagf6_ngc6121[good_ngc6121]))/(np.sqrt(len(totmagf6_ngc6121[good_ngc6121])))
print("Shift For NGC6121:", f6_difference_ngc6121)
print("Error:", stderr_ngc6121)
print()

f6_mean_ngc6397 = sum(totmagf6_ngc6397[good_ngc6397])/len(totmagf6_ngc6397[good_ngc6397])
f6_difference_ngc6397 = abs(f6_mean_ngc104-f6_mean_ngc6397)
stderr_ngc6397 = (np.std(totmagf6_ngc6397[good_ngc6397]))/(np.sqrt(len(totmagf6_ngc6397[good_ngc6397])))
print("Shift For NGC6397:", f6_difference_ngc6397)
print("Error:", stderr_ngc6397)
print()

f6_mean_missing4 = sum(totmagf6_missing_4[good_missing4])/len(totmagf6_missing_4[good_missing4])
f6_difference_missing4 = abs(f6_mean_ngc104-f6_mean_missing4)
stderr_missing4 = (np.std(totmagf6_missing_4[good_missing4]))/(np.sqrt(len(totmagf6_missing_4[good_missing4])))
print("Shift For Missing4:", f6_difference_missing4)
print("Error:", stderr_missing4)
print()

f6_mean_missing5 = sum(totmagf6_missing_5[good_missing5])/len(totmagf6_missing_5[good_missing5])
f6_difference_missing5 = abs(f6_mean_ngc104-f6_mean_missing5)
stderr_missing5 = (np.std(totmagf6_missing_5[good_missing5]))/(np.sqrt(len(totmagf6_missing_5[good_missing5])))
print("Shift For Missing5:", f6_difference_missing5)
print("Error:", stderr_missing5)
print()


f6_mean_ngc6838 = sum(totmagf6_ngc6838[good_ngc6838])/len(totmagf6_ngc6838[good_ngc6838])
f6_difference_ngc6838 = abs(f6_mean_ngc104-f6_mean_ngc6838)
stderr_ngc6838 = (np.std(totmagf6_ngc6838[good_ngc6838]))/(np.sqrt(len(totmagf6_ngc6838[good_ngc6838])))
print("Shift For NGC6838:", f6_difference_ngc6838)
print("Error:", stderr_ngc6838)
print()

f6_mean_ngc4833 = sum(totmagf6_ngc4833[good_ngc4833])/len(totmagf6_ngc4833[good_ngc4833])
f6_difference_ngc4833 = abs(f6_mean_ngc104-f6_mean_ngc4833)
stderr_ngc4833 = (np.std(totmagf6_ngc4833[good_ngc4833]))/(np.sqrt(len(totmagf6_ngc4833[good_ngc4833])))
print("Shift For NGC4833:", f6_difference_ngc4833)
print("Error:", stderr_ngc4833)
print()
# Out:
# 4. Determine the vertical shift and error value using NGC104 as the reference:
#
# Shift For E3: 0.08273835516740036
# Error: 0.6789806630094412
#
# Shift For NGCC362: 0.5400394226103735
# Error: 0.06396959205302973
#
# Shift For Missing1: 0.5709633992185701
# Error: 0.10103818842276947
#
# Shift For NGC6218: 0.22907497816593647
# Error: 0.11845518737855633
#
# Shift For Missing2: 0.4994773311070979
# Error: 0.09878739019512843
#
# Shift For NGC6656: 0.28931704120320134
# Error: 0.04216106569802189
#
# Shift For NGC6254: 0.0979903270031599
# Error: 0.08007423940329499
#
# Shift For Missing3: 0.9031515819395288
# Error: 0.0693893895209295
#
# Shift For NGC6121: 0.3101713769742567
# Error: 0.11666123854355753
#
# Shift For NGC6397: 0.9754783551673967
# Error: 0.12912015217417258
#
# Shift For Missing4: 0.6835683114992719
# Error: 0.0951414342373539
#
# Shift For Missing5: 0.12089140315703517
# Error: 0.058335217119484056
#
# Shift For NGC6838: 0.24628125267573608
# ...

# %%
print("5. Compute the Distance Moduli:")
print()

ref_ngc104 = 13.37

def distmod(difference): 
    a = difference
    b = (a + ref_ngc104)
    return (b)

ref_e3 = distmod(f6_difference_e3)
print("Dist Mod for E3:      ", ref_e3)

ref_ngc362 = distmod(f6_difference_ngc362)
print("Dist Mod for NGC362:  ", ref_ngc362)

ref_missing1 = distmod(f6_difference_missing1)
print("Dist Mod for Missing1:", ref_missing1)

ref_ngc6218 = distmod(f6_difference_ngc6218)
print("Dist Mod for NGC6218: ", ref_ngc6218)

ref_missing2 = distmod(f6_difference_missing2)
print("Dist Mod for Missing2:", ref_missing2)

ref_ngc6656 = distmod(f6_difference_ngc6656)
print("Dist Mod for NGC6656: ", ref_ngc6656)

ref_ngc6254 = distmod(f6_difference_ngc6254)
print("Dist Mod for NGC6254: ", ref_ngc6254)

ref_missing3 = distmod(f6_difference_missing3)
print("Dist Mod for Missing3:", ref_missing3)

ref_ngc6121 = distmod(f6_difference_ngc6121)
print("Dist Mod for NGC6121: ", ref_ngc6121)

ref_ngc6397 = distmod(f6_difference_ngc6397)
print("Dist Mod for NGC6397: ", ref_ngc6397)

ref_missing4 = distmod(f6_difference_missing4)
print("Dist Mod for Missing4:", ref_missing4)

ref_missing5 = distmod(f6_difference_missing5)
print("Dist Mod for Missing5:", ref_missing5)

ref_ngc6838 = distmod(f6_difference_ngc6838)
print("Dist Mod for NGC6838: ", ref_ngc6838)

ref_ngc4833 = distmod(f6_difference_ngc4833)
print("Dist Mod for NGC4833: ", ref_ngc4833)

distcalc = [ref_e3, ref_ngc362, ref_missing1, ref_ngc6218, ref_missing2, ref_ngc6656, ref_ngc6254, ref_missing3, ref_ngc6121, ref_ngc6397, ref_missing4, ref_missing5, ref_ngc6838, ref_ngc4833]
# Out:
# 5. Compute the Distance Moduli:
#
# Dist Mod for E3:       13.4527383551674
# Dist Mod for NGC362:   13.910039422610373
# Dist Mod for Missing1: 13.94096339921857
# Dist Mod for NGC6218:  13.599074978165936
# Dist Mod for Missing2: 13.869477331107097
# Dist Mod for NGC6656:  13.6593170412032
# Dist Mod for NGC6254:  13.46799032700316
# Dist Mod for Missing3: 14.273151581939528
# Dist Mod for NGC6121:  13.680171376974256
# Dist Mod for NGC6397:  14.345478355167396
# Dist Mod for Missing4: 14.053568311499271
# Dist Mod for Missing5: 13.490891403157034
# Dist Mod for NGC6838:  13.616281252675735
# Dist Mod for NGC4833:  14.039148650482305

# %%
print("6. Compare Apparent Moduli and Make a Plot")
#At this point, I was told to use the RA and Dec to find out which object was which 
#Online References: 
ref_web_e3 = 15.47
ref_web_ngc362 = 14.83
ref_web_ngc6362 = 14.68 #Missing 1?
ref_web_ngc6218 = 14.01
#ref_web_ngc3201 = 14.20 #missing 2? or 
ref_web_ngc6656 = 13.60
ref_ngc104 = 13.37
ref_web_ngc6254 = 14.08
ref_web_ngc6809 = 13.89 #Missing 3
ref_web_ngc6121 = 12.82
ref_web_ngc6397 = 12.37
ref_web_ngc6752 = 13.13 #Missing 4
ref_web_ngc5139 = 13.94 #Missing 5 
ref_web_ngc6838 = 13.80 #Missing 2????
ref_web_ngc4833 = 15.08

distweb = [ref_web_e3, ref_web_ngc362, ref_web_ngc6362, ref_web_ngc6218, ref_web_ngc6838, ref_web_ngc6656, ref_web_ngc6254, ref_web_ngc6809, ref_web_ngc6121, ref_web_ngc6397, ref_web_ngc6752, ref_web_ngc5139, ref_web_ngc6838, ref_web_ngc4833]
ycomparison = []

for i in range (len(distcalc)):
    differencee = distcalc[i]-distweb[i]
    ycomparison.append(differencee)

xcomparison = distweb

#Graph:
plt.title('Published Distance Modulus vs Difference')  
ahh = np.polyfit(xcomparison, ycomparison, 1)
bhh = np.poly1d(ahh)
plt.scatter(xcomparison,ycomparison)
plt.plot(xcomparison, bhh(xcomparison), "r")
plt.xlabel("Published Value")
plt.ylabel("Comparison")
plt.show()

#Stats:
print("    Statitsics:")
meandiff = (sum(ycomparison)/len(ycomparison))
meanstddev = np.std(ycomparison)     
print("      Mean:  ", meandiff)
print("      Std Dev:", meanstddev)
# Out:
# 6. Compare Apparent Moduli and Make a Plot
#     Statitsics:
#       Mean:   -0.15012201525919583
#       Std Dev: 0.950905996130833

# %%
print("7. Test for Correlation")
#Got these values from the http://physwww.mcmaster.ca/~harris/mwgc.dat website 
#Reddening 
r_e3 = 0.30
r_ngc362 = 0.03
r_ngc6362 = 0.09
r_ngc6218 = 0.19
#r_ngc3201 = 0.24 
r_ngc6656 = 0.34
r_ngc104 = 0.04
r_ngc6254 = 0.28
r_ngc6809 = 0.08
r_ngc6121 = 0.35
r_ngc6397 = 0.18
r_ngc6752 = 0.04
r_ngc5139 = 0.12
r_ngc6838 = 0.25
r_ngc4833 = 0.32

redd = [r_e3, r_ngc362, r_ngc6362, r_ngc6218, r_ngc6838, r_ngc6656, r_ngc6254, r_ngc6809, r_ngc6121, r_ngc6397, r_ngc6752, r_ngc5139, r_ngc6838, r_ngc4833]

#Graph:
plt.title('Actual Values Correlated with Reddening')  
ehh = np.polyfit(redd, ycomparison, 1)
fhh = np.poly1d(ehh)
plt.scatter(redd,ycomparison)
plt.plot(redd, fhh(redd), "r")
plt.xlabel("Reddening")
plt.ylabel("Comparison")
plt.show()
# Out:
# 7. Test for Correlation

# %%
print("8. Plot of Distance Moduli Difference vs Metal Abundances")

#Metallicity [Fe/H]:
m_e3 = -0.83
m_ngc362 = -1.26
m_ngc6362 = -0.99
m_ngc6218 = -1.37
#m_ngc3201 = -1.59 
m_ngc6656 = -1.70
m_ngc104 = -0.72
m_ngc6254 = -1.56
m_ngc6809 = -1.94
m_ngc6121 = -1.16
m_ngc6397 = -2.02
m_ngc6752 = -1.54
m_ngc5139 = -1.53
m_ngc6838 = -0.78
m_ngc4833 = -1.85

metal = [m_e3, m_ngc362, m_ngc6362, m_ngc6218, m_ngc6838, m_ngc6656, m_ngc6254, m_ngc6809, m_ngc6121, m_ngc6397, m_ngc6752, m_ngc5139, m_ngc6838, m_ngc4833]

#Graph:
plt.title('Distance Modulus vs Metal Abundances')  
chh = np.polyfit(metal, ycomparison, 1)
dhh = np.poly1d(chh)
plt.scatter(metal,ycomparison)
plt.plot(metal, dhh(metal), "r")
plt.xlabel("Metallicity")
plt.ylabel("Comparison")
plt.show()
# Out:
# 8. Plot of Distance Moduli Difference vs Metal Abundances
